# %% [markdown]
# # Pandas Functions, Columns
# * ! pip install numpy pandas pandera
# ## DataFrame
#  * add new column
#    * one column
#    * two or more Columns
#  * delete column
#  * change data type of columns
#  * map
#  * apply
#     * apply on one column
#     * more then one column
# * concat
#   * axis
#    * axis = 0 (top to bottom)
#    * axis = 1 (left to right)
# * describe DataFrame
#   * display (df.info()) # total index, columns names and data type, total file cells
#   * display ( df.describe()) # mean, std, min, statical properties | apply only numeric columns
#   * display (df.head()) # first 5 rows
#   * dispaly (df.tail()) # last 5 rows
# * DataFrame.sample # select sample till 99 and upto 100 that will population

# %%
import pandas as pd
import pandera as pa
import numpy as np
from nptyping import NDArray, Shape, Int64
from typing import Any

# %%
total : int =10000
s1 : NDArray[Shape[str(total)], Int64] = np.random.randint(80, 100, total)
print (s1)
ss1 : pd.Series = pd.Series(s1)
print (len(s1))
print (ss1)
# Out:
# [99 94 83 ... 96 88 82]
# 10000
# 0       99
# 1       94
# 2       83
# 3       95
# 4       80
#         ..
# 9995    80
# 9996    83
# 9997    96
# 9998    88
# 9999    82
# Length: 10000, dtype: int32

# %%
total : int =10000
s1 : NDArray[Shape[str(total)+"5"], Int64] = np.random.randint(80, 100, (total,5))
ss1 : pd.DataFrame = pd.DataFrame(s1, columns=['s1', 's2', 's3', 's4', 's5'])

s2 : NDArray[Shape[str(total)+"5"], Int64] = np.random.randint(79, 89,(total,5))
ss2 : pd.DataFrame = pd.DataFrame(s2, columns=['s1', 's2', 's3', 's4', 's5'])

s3 : NDArray[Shape[str(total)+"5"], Int64] = np.random.randint(60, 69,(total,5))
ss3 : pd.DataFrame = pd.DataFrame(s3, columns=['s1', 's2', 's3', 's4', 's5'])

s4 : NDArray[Shape[str(total)+"5"], Int64] = np.random.randint(50, 59,(total,5))
ss4 : pd.DataFrame = pd.DataFrame(s4, columns=['s1', 's2', 's3', 's4', 's5'])

s5 : NDArray[Shape[str(total)+"5"], Int64] = np.random.randint(40, 49, (total,5))
ss5 : pd.DataFrame = pd.DataFrame(s5, columns=['s1', 's2', 's3', 's4', 's5'])

s6 : NDArray[Shape[str(total)+"5"], Int64] = np.random.randint(30, 39, (total,5))
ss6 : pd.DataFrame = pd.DataFrame(s6, columns=['s1', 's2', 's3', 's4', 's5'])

s7 : NDArray[Shape[str(total)+"5"], Int64] = np.random.randint(0, 29,(total,5))
ss7 : pd.DataFrame = pd.DataFrame(s7, columns=['s1', 's2', 's3', 's4', 's5'])

"""s8 : NDArray[Shape[str(total)+"5"], Int64] = np.random.randint(0, 19, (total,5))
ss8 : pd.DataFrame = pd.DataFrame(s8, columns=['s1', 's2', 's3', 's4', 's5'])

s9 : NDArray[Shape[str(total)+"5"], Int64] = np.random.randint(90, 100, (total,5))
ss9 : pd.DataFrame = pd.DataFrame(s9, columns=['s1', 's2', 's3', 's4', 's5'])
"""
print (ss1)
print (ss2)
print (ss3)
print (ss4)
print (ss5)
print (ss6)
print (ss7)
#print (ss8)
#print (ss9)
# Out:
#       s1  s2  s3  s4  s5
# 0     97  91  96  88  92
# 1     94  90  83  90  98
# 2     87  83  93  98  91
# 3     90  85  94  89  89
# 4     96  89  95  86  88
# ...   ..  ..  ..  ..  ..
# 9995  80  93  80  82  92
# 9996  82  88  85  95  88
# 9997  83  85  93  94  92
# 9998  81  87  84  97  80
# 9999  82  80  84  83  82
#
# [10000 rows x 5 columns]
#       s1  s2  s3  s4  s5
# 0     80  84  85  88  88
# 1     82  84  88  83  88
# 2     84  83  81  83  79
# 3     81  83  88  81  85
# 4     84  80  79  86  79
# ...   ..  ..  ..  ..  ..
# 9995  87  83  79  82  84
# 9996  86  79  88  88  79
# 9997  81  87  85  80  79
# 9998  83  88  88  81  81
# 9999  81  84  88  87  88
#
# [10000 rows x 5 columns]
#       s1  s2  s3  s4  s5
# 0     68  68  65  63  64
# 1     60  61  68  65  66
# 2     66  60  63  63  67
# 3     61  67  65  61  64
# 4     66  64  65  68  66
# ...   ..  ..  ..  ..  ..
# 9995  66  62  68  68  60
# 9996  60  64  64  63  64
# 9997  65  66  65  61  62
# 9998  63  64  65  65  67
# 9999  62  62  68  62  63
#
# [10000 rows x 5 columns]
#       s1  s2  s3  s4  s5
# 0     55  51  53  51  51
# 1     55  56  56  57  57
# 2     58  50  56  52  50
# 3     52  57  55  50  52
# 4     58  58  52  51  50
# ...   ..  ..  ..  ..  ..
# 9995  53  51  52  57  55
# 9996  51  55  52  51  56
# 9997  55  52  57  55  51
# 9998  56  53  50  50  50
# 9999  50  54  52  52  52
#
# [10000 rows x 5 columns]
#       s1  s2  s3  s4  s5
# 0     42  44  46  44  46
# 1     40  44  40  40  41
# 2     48  41  46  48  40
# 3     48  43  43  48  45
# 4     43  44  42  45  47
# ...   ..  ..  ..  ..  ..
# 9995  41  45  40  47  48
# 9996  40  46  48  43  43
# 9997  41  42  41  41  47
# 9998  43  40  42  41  45
# 9999  43  43  44  45  45
#
# [10000 rows x 5 columns]
#       s1  s2  s3  s4  s5
# 0     37  33  31  38  36
# 1     34  36  32  35  30
# 2     30  37  38  33  33
# 3     35  31  31  30  35
# 4     32  38  33  35  33
# ...   ..  ..  ..  ..  ..
# 9995  35  30  30  31  34
# 9996  33  32  37  32  32
# 9997  31  35  38  36  31
# 9998  36  37  30  36  37
# 9999  34  34  34  34  34
#
# [10000 rows x 5 columns]
#       s1  s2  s3  s4  s5
# 0     19   8  25  12  26
# 1     16  11   2  21   6
# 2      4  16  21  22  24
# 3     28  12   1  12   6
# 4     22  21  17  21   6
# ...   ..  ..  ..  ..  ..
# 9995  17   2  28  26   4
# 9996  12  11  13  16  11
# 9997   0  28  20  16   3
# 9998  28   6  17  19   1
# 9999  25   4  28  28  17
#
# [10000 rows x 5 columns]

# %%
df : pd.DataFrame = pd.concat([ss1])

display (df.info())
print ("============")
display ( df.describe())
print ("============")
display (df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   s1      10000 non-null  int32
#  1   s2      10000 non-null  int32
#  2   s3      10000 non-null  int32
#  3   s4      10000 non-null  int32
#  4   s5      10000 non-null  int32
# dtypes: int32(5)
# memory usage: 195.4 KB
# None
# ============
#                  s1            s2            s3            s4            s5
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean      89.526900     89.604600     89.435800     89.519600     89.486000
# std        5.789217      5.770857      5.802314      5.736855      5.748644
# min       80.000000     80.000000     80.000000     80.000000     80.000000
# 25%       85.000000     85.000000     84.000000     84.000000     84.000000
# 50%       89.000000     90.000000     89.000000     90.000000     89.000000
# 75%       95.000000     95.000000     94.000000     94.000000     94.000000
# max       99.000000     99.000000     99.000000     99.000000     99.000000
# ============
#    s1  s2  s3  s4  s5
# 0  97  91  96  88  92
# 1  94  90  83  90  98
# 2  87  83  93  98  91
# 3  90  85  94  89  89
# 4  96  89  95  86  88

# %%
df : pd.DataFrame = pd.concat([ss1, ss2,ss3,ss4,ss5,ss6,ss7])

display (df.info())
print ("============")
display ( df.describe())
print ("============")
display (df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 70000 entries, 0 to 9999
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   s1      70000 non-null  int32
#  1   s2      70000 non-null  int32
#  2   s3      70000 non-null  int32
#  3   s4      70000 non-null  int32
#  4   s5      70000 non-null  int32
# dtypes: int32(5)
# memory usage: 1.9 MB
# None
# ============
#                  s1            s2            s3            s4            s5
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean      54.722229     54.745729     54.701229     54.709057     54.714729
# std       25.283520     25.267989     25.287625     25.261004     25.284828
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%       36.000000     36.000000     36.000000     36.000000     36.000000
# 50%       54.000000     54.000000     54.000000     54.000000     54.000000
# 75%       80.000000     81.000000     81.000000     81.000000     81.000000
# max       99.000000     99.000000     99.000000     99.000000     99.000000
# ============
#    s1  s2  s3  s4  s5
# 0  97  91  96  88  92
# 1  94  90  83  90  98
# 2  87  83  93  98  91
# 3  90  85  94  89  89
# 4  96  89  95  86  88

# %%
df : pd.DataFrame = pd.concat([ss1, ss2,ss3,ss4,ss5,ss6,ss7])

display (df.info())
print ("============================================================")
display ( df.describe())
print ("================================================")
display (df.head())
print ("================================================")
display (df.tail())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 70000 entries, 0 to 9999
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   s1      70000 non-null  int32
#  1   s2      70000 non-null  int32
#  2   s3      70000 non-null  int32
#  3   s4      70000 non-null  int32
#  4   s5      70000 non-null  int32
# dtypes: int32(5)
# memory usage: 1.9 MB
# None
# ============================================================
#                  s1            s2            s3            s4            s5
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean      54.722229     54.745729     54.701229     54.709057     54.714729
# std       25.283520     25.267989     25.287625     25.261004     25.284828
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%       36.000000     36.000000     36.000000     36.000000     36.000000
# 50%       54.000000     54.000000     54.000000     54.000000     54.000000
# 75%       80.000000     81.000000     81.000000     81.000000     81.000000
# max       99.000000     99.000000     99.000000     99.000000     99.000000
# ================================================
#    s1  s2  s3  s4  s5
# 0  97  91  96  88  92
# 1  94  90  83  90  98
# 2  87  83  93  98  91
# 3  90  85  94  89  89
# 4  96  89  95  86  88
# ================================================
#       s1  s2  s3  s4  s5
# 9995  17   2  28  26   4
# 9996  12  11  13  16  11
# 9997   0  28  20  16   3
# 9998  28   6  17  19   1
# 9999  25   4  28  28  17

# %%
df.to_csv("student.csv", index=False)

# %%
df1 : pd.DataFrame = pd.read_csv("./student.csv")
df1.head()
# Out:
#    s1  s2  s3  s4  s5
# 0  97  91  96  88  92
# 1  94  90  83  90  98
# 2  87  83  93  98  91
# 3  90  85  94  89  89
# 4  96  89  95  86  88

# %%
df : pd.DataFrame = pd.concat([ss1, ss2,ss3,ss4,ss5,ss6,ss7]).reset_index(drop=True)

display (df.info())
print ("========================================================")
display ( df.describe())
print ("================================================")
display (df.head())
print ("=======================================")
display (df.tail())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   s1      70000 non-null  int32
#  1   s2      70000 non-null  int32
#  2   s3      70000 non-null  int32
#  3   s4      70000 non-null  int32
#  4   s5      70000 non-null  int32
# dtypes: int32(5)
# memory usage: 1.3 MB
# None
# ========================================================
#                  s1            s2            s3            s4            s5
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean      54.722229     54.745729     54.701229     54.709057     54.714729
# std       25.283520     25.267989     25.287625     25.261004     25.284828
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%       36.000000     36.000000     36.000000     36.000000     36.000000
# 50%       54.000000     54.000000     54.000000     54.000000     54.000000
# 75%       80.000000     81.000000     81.000000     81.000000     81.000000
# max       99.000000     99.000000     99.000000     99.000000     99.000000
# ================================================
#    s1  s2  s3  s4  s5
# 0  97  91  96  88  92
# 1  94  90  83  90  98
# 2  87  83  93  98  91
# 3  90  85  94  89  89
# 4  96  89  95  86  88
# =======================================
#        s1  s2  s3  s4  s5
# 69995  17   2  28  26   4
# 69996  12  11  13  16  11
# 69997   0  28  20  16   3
# 69998  28   6  17  19   1
# 69999  25   4  28  28  17

# %% [markdown]
# # Apply operation on columns
# * Extract one column from Data Frame
#   * DataFrame['column]
#     * add new colum
#     * get column with space between columns text
#   * DataFrame.column
#     *  notadd new colum
#     *  not get column with space between columns text
#   * Extract two or more columns from DataFrame
#     * DataFrame[['column1', 'column2']]
#     * DataFrame.column1, DataFrame.column2
#      * pass list into DataFrame

# %%
df['s5']
# df ['s5 phython']
# Out:
# 0        92
# 1        98
# 2        91
# 3        89
# 4        88
#          ..
# 69995     4
# 69996    11
# 69997     3
# 69998     1
# 69999    17
# Name: s5, Length: 70000, dtype: int32

# %%
df.s5
# Out:
# 0        92
# 1        98
# 2        91
# 3        89
# 4        88
#          ..
# 69995     4
# 69996    11
# 69997     3
# 69998     1
# 69999    17
# Name: s5, Length: 70000, dtype: int32

# %%
df [['s1', 's2', 's3', 's1']]
# Out:
#        s1  s2  s3  s1
# 0      97  91  96  97
# 1      94  90  83  94
# 2      87  83  93  87
# 3      90  85  94  90
# 4      96  89  95  96
# ...    ..  ..  ..  ..
# 69995  17   2  28  17
# 69996  12  11  13  12
# 69997   0  28  20   0
# 69998  28   6  17  28
# 69999  25   4  28  25
#
# [70000 rows x 4 columns]

# %%
df.s1, df.s3
# Out:
# (0        97
#  1        94
#  2        87
#  3        90
#  4        96
#           ..
#  69995    17
#  69996    12
#  69997     0
#  69998    28
#  69999    25
#  Name: s1, Length: 70000, dtype: int32,
#  0        96
#  1        83
#  2        93
#  3        94
#  4        95
#           ..
#  69995    28
#  69996    13
#  69997    20
#  69998    17
#  69999    28
#  Name: s3, Length: 70000, dtype: int32)

# %% [markdown]
# # Add new column
#  * Addition operation on column

# %%
df.head()
# Out:
#    s1  s2  s3  s4  s5
# 0  97  91  96  88  92
# 1  94  90  83  90  98
# 2  87  83  93  98  91
# 3  90  85  94  89  89
# 4  96  89  95  86  88

# %%
df['Total'] = 500 # add new column
df['Total'] = 300 # update new column
del df['Total']  # delete column

df
# Out:
#        s1  s2  s3  s4  s5
# 0      97  91  96  88  92
# 1      94  90  83  90  98
# 2      87  83  93  98  91
# 3      90  85  94  89  89
# 4      96  89  95  86  88
# ...    ..  ..  ..  ..  ..
# 69995  17   2  28  26   4
# 69996  12  11  13  16  11
# 69997   0  28  20  16   3
# 69998  28   6  17  19   1
# 69999  25   4  28  28  17
#
# [70000 rows x 5 columns]

# %%
#df.Total = 500 #  not add new column
df['Total'] = 500 # add new column
# del df.Total  #  not delete column
#df.toal = 300 # update column

df
# Out:
#        s1  s2  s3  s4  s5  Total
# 0      97  91  96  88  92    500
# 1      94  90  83  90  98    500
# 2      87  83  93  98  91    500
# 3      90  85  94  89  89    500
# 4      96  89  95  86  88    500
# ...    ..  ..  ..  ..  ..    ...
# 69995  17   2  28  26   4    500
# 69996  12  11  13  16  11    500
# 69997   0  28  20  16   3    500
# 69998  28   6  17  19   1    500
# 69999  25   4  28  28  17    500
#
# [70000 rows x 6 columns]

# %%
display (df.head())
# Out:
#    s1  s2  s3  s4  s5  Total
# 0  97  91  96  88  92    500
# 1  94  90  83  90  98    500
# 2  87  83  93  98  91    500
# 3  90  85  94  89  89    500
# 4  96  89  95  86  88    500

# %%
df['s1'] + df['s2'] +df['s3'] + df['s4'] + df['s5']
# Out:
# 0        464
# 1        455
# 2        452
# 3        447
# 4        454
#         ...
# 69995     77
# 69996     63
# 69997     67
# 69998     71
# 69999    102
# Length: 70000, dtype: int32

# %%
df['obtained'] = df['s1'] + df['s2'] +df['s3'] + df['s4'] + df['s5']
df
# Out:
#        s1  s2  s3  s4  s5  Total  obtained
# 0      97  91  96  88  92    500       464
# 1      94  90  83  90  98    500       455
# 2      87  83  93  98  91    500       452
# 3      90  85  94  89  89    500       447
# 4      96  89  95  86  88    500       454
# ...    ..  ..  ..  ..  ..    ...       ...
# 69995  17   2  28  26   4    500        77
# 69996  12  11  13  16  11    500        63
# 69997   0  28  20  16   3    500        67
# 69998  28   6  17  19   1    500        71
# 69999  25   4  28  28  17    500       102
#
# [70000 rows x 7 columns]

# %%
df['Percentage'] = df['obtained'] / df['Total'] * 100
df
# Out:
#        s1  s2  s3  s4  s5  Total  obtained  Percentage
# 0      97  91  96  88  92    500       464        92.8
# 1      94  90  83  90  98    500       455        91.0
# 2      87  83  93  98  91    500       452        90.4
# 3      90  85  94  89  89    500       447        89.4
# 4      96  89  95  86  88    500       454        90.8
# ...    ..  ..  ..  ..  ..    ...       ...         ...
# 69995  17   2  28  26   4    500        77        15.4
# 69996  12  11  13  16  11    500        63        12.6
# 69997   0  28  20  16   3    500        67        13.4
# 69998  28   6  17  19   1    500        71        14.2
# 69999  25   4  28  28  17    500       102        20.4
#
# [70000 rows x 8 columns]

# %% [markdown]
# # apply custom functions on coloumns (SeriesData)

# %%
def grade(per : int) -> str:
    if per >= 80:
        return "A+"
    elif per >= 70:
        return "A"
    elif per >= 60:
        return "B"
    elif per >= 50:
        return "C"
    elif per >= 40:
        return "D"
    elif per >= 33:
        return "E"
    else:
        return "F"

grade (82)
grade (30)
# Out:
# 'F'

# %%
df['Percentage'].apply(grade)
# Out:
# 0        A+
# 1        A+
# 2        A+
# 3        A+
# 4        A+
#          ..
# 69995     F
# 69996     F
# 69997     F
# 69998     F
# 69999     F
# Name: Percentage, Length: 70000, dtype: object

# %%
df['Grade'] = df['Percentage'].apply(grade)
df
# Out:
#        s1  s2  s3  s4  s5  Total  obtained  Percentage Grade
# 0      97  91  96  88  92    500       464        92.8    A+
# 1      94  90  83  90  98    500       455        91.0    A+
# 2      87  83  93  98  91    500       452        90.4    A+
# 3      90  85  94  89  89    500       447        89.4    A+
# 4      96  89  95  86  88    500       454        90.8    A+
# ...    ..  ..  ..  ..  ..    ...       ...         ...   ...
# 69995  17   2  28  26   4    500        77        15.4     F
# 69996  12  11  13  16  11    500        63        12.6     F
# 69997   0  28  20  16   3    500        67        13.4     F
# 69998  28   6  17  19   1    500        71        14.2     F
# 69999  25   4  28  28  17    500       102        20.4     F
#
# [70000 rows x 9 columns]

# %%
df.sample
# Out:
# <bound method NDFrame.sample of        s1  s2  s3  s4  s5  Total  obtained  Percentage Grade
# 0      97  91  96  88  92    500       464        92.8    A+
# 1      94  90  83  90  98    500       455        91.0    A+
# 2      87  83  93  98  91    500       452        90.4    A+
# 3      90  85  94  89  89    500       447        89.4    A+
# 4      96  89  95  86  88    500       454        90.8    A+
# ...    ..  ..  ..  ..  ..    ...       ...         ...   ...
# 69995  17   2  28  26   4    500        77        15.4     F
# 69996  12  11  13  16  11    500        63        12.6     F
# 69997   0  28  20  16   3    500        67        13.4     F
# 69998  28   6  17  19   1    500        71        14.2     F
# 69999  25   4  28  28  17    500       102        20.4     F
#
# [70000 rows x 9 columns]>

# %%
df1
# Out:
#        s1  s2  s3  s4  s5
# 0      97  91  96  88  92
# 1      94  90  83  90  98
# 2      87  83  93  98  91
# 3      90  85  94  89  89
# 4      96  89  95  86  88
# ...    ..  ..  ..  ..  ..
# 69995  17   2  28  26   4
# 69996  12  11  13  16  11
# 69997   0  28  20  16   3
# 69998  28   6  17  19   1
# 69999  25   4  28  28  17
#
# [70000 rows x 5 columns]

# %%
df.to_excel ('student.xlsx', index = False)

# %%
dxl : pd.DataFrame = pd.read_excel('student.xlsx')
dxl
# Out:
#        s1  s2  s3  s4  s5  Total  obtained  Percentage Grade
# 0      91  90  96  92  98    500       467        93.4    A+
# 1      97  89  91  92  84    500       453        90.6    A+
# 2      93  89  90  84  98    500       454        90.8    A+
# 3      98  99  85  99  93    500       474        94.8    A+
# 4      93  86  88  88  86    500       441        88.2    A+
# ...    ..  ..  ..  ..  ..    ...       ...         ...   ...
# 69995  22   0   2  26  13    500        63        12.6     F
# 69996  17  27   9  24  25    500       102        20.4     F
# 69997   2  24   6   2  20    500        54        10.8     F
# 69998  24   7   4  19  25    500        79        15.8     F
# 69999   4  22  25  17  25    500        93        18.6     F
#
# [70000 rows x 9 columns]
